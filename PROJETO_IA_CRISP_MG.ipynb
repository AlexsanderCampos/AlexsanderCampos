# %% [markdown]
# # Grupo -  Estudo por Rodovia - BR 381 / 262 MG - 2/2021
#
# 1.   Alexsander Campos - UC18100588
# 2.   Barton Túlio - UC17101333
# 3.   Iana Corrêa Reis - UC16200904
# 4.   Igor Ribeiro Lima Martins - UC21103937
# 5.   João Victor Silva Costa - UC18100295

# %% [markdown]
# # **Projeto de Ciência de Dados [Metodologia CRISP-DM]**

# %% [markdown]
# # **1. COMPREENSÃO DO NEGÓCIO**

# %% [markdown]
# # **1.1	Determinando os objetivos do negócio**

# %% [markdown]
# ## **Informações básicas sobre a situação atual do negócio**

# %% [markdown]
# <p align="justify">O projeto está relacionado com os acidentes ocorridos em rodovias, desta forma o setor afetado pelo projeto é o Sistema Nacional de Trânsito (SNT). Atualmente é possivel encontrar diversos estudos e artigos sobre acidentes em rodovias no geral, mas a respeito de acidentes ocorridos nas rodovias BR-381 e BR-262 do estado de Minas Gerais, existem poucos. Portanto não se tem uma solução atual conhecida.</p>
#
# <p align="justify">Nenhum dos estudantes possui conhecimentos prévios em mineração de dados, mas sim em outras áreas e diferentes tipos de linguagens de programação, como c, java e python. O uso do ambiente Google Colab também será de grande ajuda pois oferece versatibilidade e é muito usado em Ciência de Dados.</p>

# %% [markdown]
# ## **Objetivos do negócio do ponto de vista dos tomadores de decisão**

# %% [markdown]
# <p align="justify">O projeto tem como finalidade fazer um estudo a respeito dos acidentes ocorridos nas rodovias BR-381 e BR-262 do estado de Minas Gerais. Uma análise será feita sobre os tipos de ocorrências, por exemplo, <i>"como tem sido a progressão desses casos nos últimos 5 anos"</i>.</p>

# %% [markdown]
# ## **Critérios de sucesso do projeto**

# %% [markdown]
# O sucesso do projeto e da mineração de dados está na compreensão sobre os acidentes ocorridos nas rodovias BR-381 e BR-262 através da leitura, interpretação e visualização dos dados.
#
# As expectativas esperadas pelo grupo são de com o desenvolvimento e finalização do projeto, estes compreendam sobre a importância e a necessidade da mineração de dados.

# %% [markdown]
# # **1.2	Avaliando a situação**

# %% [markdown]
# ## **Inventário de recursos**

# %% [markdown]
# ### Google Collaboratory
# <p align="justify">
# Serviço de armazenamento em nuvem de notebooks voltados à criação e execução de códigos em Python, diretamente em um navegador, sem a necessidade de nenhum tipo de instalação de software em uma máquina.
# </p>
#
# ### GitHub
# <p align="justify">
# Plataforma de hospedagem de código-fonte e arquivos com controle de versão usando o Git.
# </p>
#
# ### Microsoft Excell
# <p align="justify">
# Editor de planilhas produzido pela Microsoft para computadores que utilizam o sistema operacional Microsoft Windows, além de computadores Macintosh da Apple Inc. e dispositivos móveis como o Windows Phone, Android ou o iOS.
# </p>
#
# ### Fonte dos dados
# <p align="justify">
# O site do Governo Federal do Brasil disponibiliza acesso a diferentes tipos de datasets, seguindo a política de Dados Abertos governamental, onde este é uma metodologia para a publicação de dados do governo em formatos reutilizáveis, visando o aumento da transparência e maior participação política por parte do cidadão, além de gerar diversas aplicações desenvolvidas colaborativamente pela sociedade.
# </p>
# <p align="justify">
# Neste projeto usaremos os dados abertos coletados pela Polícia Rodoviária Federal - PRF através do sistema BAT, que coleta informações referentes aos envolvidos (identificação, estado físico, se era passageiro, condutor, etc.), ao local, aos veículos, à dinâmica do acidente, etc. Os dados disponíveis têm origem nos sistemas BR-Brasil e BAT. O sistema BR-Brasil foi utilizado em nível nacional entre 2007 e 2016. O sistema BAT é utilizado desde 2017.
# </p>
#
# ### Equipe
# <p align="justify">
# Formada por estudantes dos cursos de graduação em Ciência da Computação e Economia da Universidade Católica de Brasília.
# </p>

# %% [markdown]
# ## **Riscos e contingências**

# %% [markdown]
# <p align="justify">O projeto visa ser terminado durante o período de um semestre, tempo este considerado suficiente para que a equipe busque por enriquecimento dos próprios conhecimentos e aprofundamento, manejo e análise dos dados abertos disponibilizados. Estes representam cinco anos de coleta por parte da Polícia Rodoviária Federal - PRF, nos anos de 2016 à 2020.</p>
# <p align="justify">
# Os possíveis problemas que podem aparecer são com a base de dados, mas por ser um trabalho acadêmico à poucos riscos que impossibilitem a não conclusão.
# </p>

# %% [markdown]
# ## **Levantamento da terminologia empregada**

# %% [markdown]
# Acidentes de trânsito; Acidentes por ocorrência; Acidentes por pessoa;

# %% [markdown]
# ## **Análise de custo-benefício**

# %% [markdown]
# <p align="justify">
# Não houve custos para a obtenção dos dados, já que estes são disponibilizados de forma gratuita pelo Governo Federal. Caso ocorra imprevistos em alguma das etapas deste projeto, a simplificação do mesmo pode ser a melhor saída.
# </p>

# %% [markdown]
# # **1.3	Determinando os objetivos da mineração de dados**

# %% [markdown]
# ## **Definição dos objetivos da mineração de dados**

# %% [markdown]
# *(i) Descrever o tipo de problema de mineração de dados (ex: agrupamento, classificação etc);*

# %% [markdown]
# Coletar dados sobre as causas presumíveis dos acidentes nos últimos anos nas rodovias, verificar os tipos de acidentes e os seus envolvidos.

# %% [markdown]
# *(ii) Enumerar as metas da mineração de dados (ex: predições válidas por três meses);*

# %% [markdown]
# Identificar qual a média movel de acidentes ocorrida nas rodovias BR-381 e BR-262 do estado de Minas Gerais . Analisando os dados dos acidentes nos anos de: 2016,2017,2018,2019 e 2020.

# %% [markdown]
# *(iii) Quantificar os resultados desejados em relação à situação atual (ex: indicadores de perda de clientes).*

# %% [markdown]
# Verificar a media móvel dos acidentes, verificar se existe uma sazonalidade das ocorrências de acidentes , variedade de envolvidos e principais causas que levam a esses acidentes.

# %% [markdown]
# ## **Critérios de sucesso da mineração de dados**

# %% [markdown]
# *(i) Definir e descrever os métodos para avaliação do(s) modelo(s) (ex: precisão, desempenho, etc);*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Definir critérios objetivos (numéricos) de desempenho para avaliação do sucesso da mineração de dados);*

# %% [markdown]
# xxx

# %% [markdown]
# *(iii) Especificar medidas subjetivas e determinar os responsáveis pelas avaliações.*

# %% [markdown]
# xxx

# %% [markdown]
# # **1.4	Produzindo um plano do projeto**

# %% [markdown]
# ## **Plano do projeto do ponto de vista técnico**

# %% [markdown]
# <p align="justify">O planejamento do projeto é dividido em seis etapas:</p>
#
# - Compreensão do negócio
# - Compreensão dos dados
# - Preparação dos dados
# - Modelagem
# - Avaliação
# - Implementação
#
# <p align="justify">Para cada uma delas, haverá reuniões semanais do grupo juntamente com os orientadores para discussões dos procedimentos e encaminhamentos a serem tomados em seu decorrer.</p>

# %% [markdown]
# # **2. COMPREENSÃO DOS DADOS**

# %% [markdown]
# # **2.1 Coletando dados iniciais**

# %% [markdown]
# **Importação de Bibliotecas e Leitura dos Datasets**

# %% [markdown]
# *(i) Identificar as bases de dados potencialmente relevantes para o projeto;*

# %%
import pandas as pd
import numpy as np
import datetime as dt #Módulo Datetime fornece as classes para manipulação de datas e horas.
import matplotlib.pyplot as plt
import plotly.graph_objects as go #Plotly - Biblioteca para visualização de gráficos interativos python.
from matplotlib.pyplot import figure
import seaborn as sn
import plotly.express as px

# %%
#Montando o seu drive dentro do pandas.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#dataframes "Acidentes agrupados por Pessoa"
apessoa2016 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/acidentes2016_data_corrigida.csv', encoding="ISO-8859-1", sep=';')
apessoa2017 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/acidentes2017.csv', encoding="ISO-8859-1", sep=';')
apessoa2018 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/acidentes2018.csv', encoding="ISO-8859-1", sep=';')
apessoa2019 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/acidentes2019.csv', encoding="ISO-8859-1", sep=';')
apessoa2020 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/acidentes2020.csv', encoding="ISO-8859-1", sep=';')

# %%
#dataframes "Acidentes agrupados por Ocorrência"
datatran2016 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/datatran2016_data_corrigida.csv', encoding="ISO-8859-1", sep=';')
datatran2017 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/datatran2017.csv', encoding="ISO-8859-1", sep=';')
datatran2018 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/datatran2018.csv', encoding="ISO-8859-1", sep=';')
datatran2019 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/datatran2019.csv', encoding="ISO-8859-1", sep=';')
datatran2020 = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/datatran2020.csv', encoding="ISO-8859-1", sep=';')

# %% [markdown]
# **Tratamento de datas**

# %% [markdown]
# *O motivo desse tratamento estar sendo feito agora é porque a coluna de data_inversa dos dataframes de 2016 está em um formato diferente dos dataframes dos anos seguintes.*

# %%
datatran2016.head(1)
# Out:
#       id data_inversa dia_semana  ... ignorados feridos  veiculos
# 0  36727   10/06/2016      Sexta  ...         0       0         2
#
# [1 rows x 25 columns]

# %%
datatran2017.head(1)
# Out:
#    id data_inversa dia_semana  ... regional delegacia       uop
# 0   8   2017-01-01    domingo  ...    SR-PR    DEL7/7  UOP05/PR
#
# [1 rows x 30 columns]

# %%
#Tratamento das datas dos dataframes de 2016.
datatran2016['data_inversa'] += ' ' + datatran2016['horario']
datatran2016['data_inversa']= pd.to_datetime(datatran2016['data_inversa'], format='%d/%m/%Y %H:%M:%S')

apessoa2016['data_inversa'] += ' ' + apessoa2016['horario']
apessoa2016['data_inversa']= pd.to_datetime(apessoa2016['data_inversa'], format='%d/%m/%Y %H:%M:%S')

# %%
#Tratamento das datas dos dataframes dos anos restantes.
#2017
apessoa2017['data_inversa'] += ' ' + apessoa2017['horario']
apessoa2017['data_inversa']= pd.to_datetime(apessoa2017['data_inversa'], format='%Y/%m/%d %H:%M:%S')

datatran2017['data_inversa'] += ' ' + datatran2017['horario']
datatran2017['data_inversa']= pd.to_datetime(datatran2017['data_inversa'], format='%Y/%m/%d %H:%M:%S')
#2018
apessoa2018['data_inversa'] += ' ' + apessoa2018['horario']
apessoa2018['data_inversa']= pd.to_datetime(apessoa2018['data_inversa'], format='%Y/%m/%d %H:%M:%S')

datatran2018['data_inversa'] += ' ' + datatran2018['horario']
datatran2018['data_inversa']= pd.to_datetime(datatran2018['data_inversa'], format='%Y/%m/%d %H:%M:%S')
#2019
apessoa2019['data_inversa'] += ' ' + apessoa2019['horario']
apessoa2019['data_inversa']= pd.to_datetime(apessoa2019['data_inversa'], format='%Y/%m/%d %H:%M:%S')

datatran2019['data_inversa'] += ' ' + datatran2019['horario']
datatran2019['data_inversa']= pd.to_datetime(datatran2019['data_inversa'], format='%Y/%m/%d %H:%M:%S')
#2020
apessoa2020['data_inversa'] += ' ' + apessoa2020['horario']
apessoa2020['data_inversa']= pd.to_datetime(apessoa2020['data_inversa'], format='%Y/%m/%d %H:%M:%S')

datatran2020['data_inversa'] += ' ' + datatran2020['horario']
datatran2020['data_inversa']= pd.to_datetime(datatran2020['data_inversa'], format='%Y/%m/%d %H:%M:%S')

# %% [markdown]
# **Junção dos dataframes e isolando as informações somente das BR's 381 e 262**

# %% [markdown]
# *Acidentes agrupados por ocorrência*

# %%
#Concatenação
datatran_total = pd.concat([datatran2016, datatran2017, datatran2018, datatran2019, datatran2020])

# %%
#Isolando as BRS 381 e 262 - MG - acidentes agrupados por ocorrência
x = (datatran_total.uf == 'MG') & (datatran_total.br == 381)
y = (datatran_total.uf == 'MG') & (datatran_total.br == 262)
datatran_381 = datatran_total[x]
datatran_381['Contagem'] = 1 #Adicionando coluna para contagem
datatran_262 = datatran_total[y]
datatran_262['Contagem'] = 1 #Adicionando coluna para contagem
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Concatenacao da filtragem de br's - acidentes agrupados por ocorrências
datatran_381_262 = pd.concat([datatran_381, datatran_262])

# %%
#Drop horario

dropDataFrame = datatran_381_262
to_drop = ['horario', 'dia_semana']

datatran_381_262.drop(to_drop, inplace=True, axis=1)

# %%
#Criar coluna
datatran_381_262['hora'] = datatran_381_262['data_inversa'].dt.hour
datatran_381_262['dia_da_semana'] = datatran_381_262['data_inversa'].dt.dayofweek #Segunda-0/Terça-1/Quarta-2/Quinta-3/Sexta-4/Sábado-5/Domingo-6
datatran_381_262['ano'] = datatran_381_262['data_inversa'].dt.year

# %%
datatran_381_262['mes'] = datatran_381_262['data_inversa'].dt.month

# %% [markdown]
# *Acidentes agrupados por pessoa*

# %%
#Concatenação
apessoa_total = pd.concat([apessoa2016, apessoa2017, apessoa2018, apessoa2019, apessoa2020])

# %%
#Isolando as BRS 381 e 262 - MG - acidentes agrupados por pessoa
x = (apessoa_total.uf == 'MG') & (apessoa_total.br == 381)
y = (apessoa_total.uf == 'MG') & (apessoa_total.br == 262)
apessoa_381 = apessoa_total[x]
apessoa_381['Contagem'] = 1 #Adicionando coluna para contagem
apessoa_262 = apessoa_total[y]
apessoa_262['Contagem'] = 1 #Adicionando coluna para contagem
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Concatenacao da filtragem de br's - acidentes agrupados por pessoa
apessoa_381_262 = pd.concat([apessoa_381, apessoa_262])

# %%
#Drop horario

dropDataFrame = apessoa_381_262
to_drop = ['horario', 'dia_semana']

apessoa_381_262.drop(to_drop, inplace=True, axis=1)

# %%
#Criar coluna
apessoa_381_262['hora'] = apessoa_381_262['data_inversa'].dt.hour
apessoa_381_262['dia_da_semana'] = apessoa_381_262['data_inversa'].dt.dayofweek #Segunda-0/Terça-1/Quarta-2/Quinta-3/Sexta-4/Sábado-5/Domingo-6
apessoa_381_262['ano'] = apessoa_381_262['data_inversa'].dt.year

# %% [markdown]
# *(ii) Para cada base, identificar os atributos mais promissores;*
# *(iii) Identificar atributos que pareçam irrelevantes e que podem ser excluídos;*

# %% [markdown]
# <p align="justify">Para se encontrar os atributos mais promissores ou irrelevantes é necessário se fazer correlações, com o objetivo de determinar o grau de relacionamento entre eles.</p>

# %% [markdown]
# *(iii) Verificar a necessidade de redução de dimensionalidade dos dados;*

# %%
datatran_381_262.head(2)
# Out:
#             id        data_inversa  uf  ...  hora dia_da_semana   ano
# 33  83425918.0 2016-01-01 08:30:00  MG  ...     8             4  2016
# 73  83425990.0 2016-01-01 14:30:00  MG  ...    14             4  2016
#
# [2 rows x 32 columns]

# %% [markdown]
# <p align="justify">Como o módulo de "datetime" fornece classes para manipulação de data e hora, as colunas "data_inversa" e "horario", existentes nos dataframes podem virar uma só.</p>

# %% [markdown]
# *(iv) Se você estiver considerando dados de diversas fontes, verifique a viabilidade ou possíveis problemas de se fazer sua junção;*

# %% [markdown]
# <p align="justify">Os dados das pessoas envolvidas nas ocorrências torna inviável a junção das bases por conta da variedade de dados que poderão surgir atribuídos ao mesmo acidente.</p>

# %% [markdown]
# *(v) Verificar como os valores faltantes poderão ser tratados.*

# %% [markdown]
# <p aligh="justify">Podem ser tratados das seguintes formas, excluindo os dados, mas este método só deve ser seguido em casos onde não haverá impactos significativos, pois outros dados importantes podem acabar se perdendo. A outra forma é preenchendo estes dados com outros, esta é a abordagem mais utilizada.</p>

# %% [markdown]
# # **2.2	Descrevendo os dados**

# %% [markdown]
# *(i) Verificar a formatação dos arquivos;*

# %% [markdown]
# Os arquivos estão no formato .CSV (comma-separated-values).

# %% [markdown]
# *(ii) Identificar o método usado para a captura dos dados;*

# %% [markdown]
# <p align="justify">Entre os anos de 2007 e 2016 o registro de acidentes era realizado por meio do sistema BR-Brasil. Nesse sistema o policial responsável pela ocorrência insere dados referentes aos envolvidos, ao local, aos veículos e à dinâmica do acidente.</p>
# <p align="justify">Em janeiro de 2017 o sistema BR-Brasil foi descontinuado e a PRF passou a utilizar um novo sistema denominado BAT, que coleta informações referentes aos envolvidos (identificação, estado físico, se era passageiro, condutor, etc.)para registro das ocorrências de acidentes de trânsito.</p>

# %% [markdown]
# *(iii) Levantar o tamanho da(s) base(s) de dados (número de linhas e colunas);*

# %%
#dataframe Acidentes agrupados por ocorrências.
#Retorna o número de linhas e colunas, respectivamente.
print("Colunas: {}\nLinhas:\t{}".format(datatran_381_262.shape[1], datatran_381_262.shape[0]))
# Out:
# Colunas: 32
# Linhas:	22760

# %%
#dataframe Acidentes agrupados por pessoa.
#Retorna o número de linhas e colunas, respectivamente.
print("Colunas: {}\nLinhas:\t{}".format(apessoa_381_262.shape[1], apessoa_381_262.shape[0]))
# Out:
# Colunas: 39
# Linhas:	51394

# %% [markdown]
# *(iv) Descrever significado, relacionamentos, origem, uso e tipo dos atributos de cada base de dados (dicionários de dados);*

# %% [markdown]
# *Dicionário de dados - Acidentes agrupados por ocorrência*

# %%
dic_dados_ocorrencias = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_ocorrencia/CSV/dic_dados_ocorrencias.csv', encoding="ISO-8859-1", sep = ';')

# %%
dic_dados_ocorrencias['descricao'].str.len().max()
# Out:
# 118

# %%
pd.get_option('max_colwidth') #Tamanho padrão das colunas no pandas.
# Out:
# 50

# %%
pd.set_option('max_colwidth', 130) #Mudando o tamanho da coluna para poder mostrar toda a descrição.

# %%
dic_dados_ocorrencias
# Out:
#            nome_da_variavel  ... tipo_variavel
# 0                       id   ...         int64
# 1              data_inversa  ...        object
# 2                dia_semana  ...        object
# 3                   horario  ...        object
# 4                       uf   ...        object
# 5                        br  ...       float64
# 6                        Km  ...        object
# 7                 municipio  ...        object
# 8            causa_acidente  ...        object
# 9             tipo_acidente  ...        object
# 10   classificacao_acidente  ...        object
# 11                fase_dia   ...        object
# 12             sentido_via   ...        object
# 13  condicao_meteorologica   ...        object
# 14              tipo_pista   ...        object
# 15              tracado_via  ...        object
# 16                 uso_solo  ...        object
# 17                  pessoas  ...         int64
# 18                   mortos  ...         int64
# ...

# %% [markdown]
# *Dicionário de dados - Acidentes agrupados por pessoa*

# %%
dic_dados_pessoas = pd.read_csv('/content/drive/MyDrive/IA-DF-CSV-XLSX/Acidentes_por_pessoa/CSV/dic_dados_pessoas_v2.csv', encoding="ISO-8859-1", sep = ';')

# %%
dic_dados_pessoas['descricao'].str.len().max()
# Out:
# 121

# %%
dic_dados_pessoas
# Out:
#            nome_da_variavel  ... tipo_variavel
# 0                       id   ...         int64
# 1                     pesid  ...       float64
# 2              data_inversa  ...        object
# 3                dia_semana  ...        object
# 4                   horario  ...        object
# 5                       uf   ...        object
# 6                        br  ...       float64
# 7                        km  ...        object
# 8                 municipio  ...        object
# 9            causa_acidente  ...        object
# 10            tipo_acidente  ...        object
# 11   classificacao_acidente  ...        object
# 12                fase_dia   ...        object
# 13             sentido_via   ...        object
# 14  condicao_meteorologica   ...        object
# 15              tipo_pista   ...        object
# 16              tracado_via  ...        object
# 17                 uso_solo  ...        object
# 18              id_veiculo   ...       float64
# ...

# %%
pd.set_option('max_colwidth', 50) #Setando o tamanho padrão novamente, para evitar futuros problemas.

# %% [markdown]
# (v) Calcular estatísticas básicas para os atributos-chave.

# %%
datatran_381_262.describe()
# Out:
#                  id            br  ...  dia_da_semana           ano
# count  2.276000e+04  22760.000000  ...   22760.000000  22760.000000
# mean   2.268556e+07    350.397759  ...       3.252548   2017.679482
# std    3.700543e+07     52.012387  ...       2.025892      1.411956
# min    4.700000e+01    262.000000  ...       0.000000   2016.000000
# 25%    1.019762e+05    262.000000  ...       1.000000   2016.000000
# 50%    2.246495e+05    381.000000  ...       3.000000   2017.000000
# 75%    8.343303e+07    381.000000  ...       5.000000   2019.000000
# max    8.352984e+07    381.000000  ...       6.000000   2020.000000
#
# [8 rows x 14 columns]

# %%
apessoa_381_262.describe()
# Out:
#                  id         pesid  ...  dia_da_semana           ano
# count  5.139400e+04  5.139400e+04  ...   51394.000000  51394.000000
# mean   2.088037e+07  2.111303e+07  ...       3.288769   2017.755263
# std    3.601183e+07  3.607075e+07  ...       2.036058      1.407274
# min    4.700000e+01  3.800000e+01  ...       0.000000   2016.000000
# 25%    1.047920e+05  2.289278e+05  ...       2.000000   2017.000000
# 50%    2.208780e+05  4.908505e+05  ...       4.000000   2018.000000
# 75%    3.315080e+05  7.387868e+05  ...       5.000000   2019.000000
# max    8.352984e+07  8.398793e+07  ...       6.000000   2020.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# # **2.3 Explorando os dados**

# %% [markdown]
# ## **Exploração dos dados**

# %% [markdown]
# *(i) Formular hipóteses sobre os dados;*

# %% [markdown]
# Feridos e feridos_leves terão forte relação; data_inversa deve reproduzir o valor de dia, mês e ano;  a maior causa de acidentes no trânsito é de velocidade_incompatível e em sua maioria as pessoas saem com ferimentos leves ou ilesos; falta_de_atenção_pedestre é a amostra com a maior taxa de mortalidade entre as causas de acidentes;

# %% [markdown]
# *(ii) Identificar atributos promissores para análise;*

# %% [markdown]
# causa_acidente, horario, dia_da_semana, mortos, tipo_veiculo;

# %% [markdown]
# *(iii) Enumerar novas características sobre os dados reveladas pela sua exploração dos dados;*

# %% [markdown]
# A partir do ano de 2017, novas informações foram adicionadas a base de dados, como, quantidade de feridos leves e graves, quantidade de vítimas fatais, latitude, longitude e entre outros.

# %% [markdown]
# *(iv) Relatar que mudanças nas hipóteses iniciais foram ocasionadas pela exploração dos dados;*

# %% [markdown]
# Não houve mudanças.

# %% [markdown]
#  *(v) Identificar subconjuntos particulares dos dados para uso posterior;*

# %% [markdown]
# classificacao_acidente, feridos_leves, feridos_graves, mortos e ignorados; estado_fisico, ilesos, feridos_leves, feridos_graves, mortos;

# %% [markdown]
# *(vi) Verificar se o resultado da exploração dos dados justifica a alteração dos objetivos do projeto ou da mineração de dados.*

# %% [markdown]
# Não justifica, pois os dados podem apresentar informações relevantes ao estudo, assim como, suas correlações.

# %% [markdown]
# ## **Qualidade dos dados**

# %% [markdown]
# *(i) Verificar se há valores de atributo faltantes ou em branco e explicitar o que isso significa;*

# %%
#Retorna a soma dos valores nulos encontrados.
datatran_381_262.isnull().sum()
# Out:
# id                           0
# data_inversa                 0
# uf                           0
# br                           0
# km                           0
# municipio                    0
# causa_acidente               0
# tipo_acidente                0
# classificacao_acidente       0
# fase_dia                     0
# sentido_via                  0
# condicao_metereologica       1
# tipo_pista                   0
# tracado_via                  0
# uso_solo                     0
# pessoas                      0
# mortos                       0
# feridos_leves                0
# feridos_graves               0
# ilesos                       0
# ignorados                    0
# feridos                      0
# veiculos                     0
# latitude                  6153
# longitude                 6153
# regional                  6153
# delegacia                 6153
# uop                       6190
# Contagem                     0
# hora                         0
# ...

# %%
apessoa_381_262.isnull().sum()
# Out:
# id                            0
# pesid                         0
# data_inversa                  0
# uf                            0
# br                            0
# km                            0
# municipio                     0
# causa_acidente                0
# tipo_acidente                 0
# classificacao_acidente        0
# fase_dia                      0
# sentido_via                   0
# condicao_metereologica        3
# tipo_pista                    0
# tracado_via                   0
# uso_solo                      0
# id_veiculo                  166
# tipo_veiculo                166
# marca                      2874
# ano_fabricacao_veiculo     1652
# tipo_envolvido                0
# estado_fisico                 0
# idade                      4234
# sexo                          0
# nacionalidade             38918
# naturalidade              46845
# ilesos                    12779
# feridos_leves             12779
# feridos_graves            12779
# ...

# %% [markdown]
# *Os dataframes de 2016 - acidentes agrupados por ocorrências e por pessoa, não contêm as colunas de latitude, longitude, regional, delegacia e uop. Já o segundo conta com ainda mais colunas faltantes que são, ilesos, feridos_leves, feridos_graves e mortos.*
#
# *Os dataframes de 2017 em diante de acidentes agrupados por pessoa, não possuem as colunas de nacionalidade e naturalidade.*
#
# *Fazendo assim com que a contagem de dados faltantes referentes a essas informações seja tão alta.*

# %% [markdown]
# *(ii) Verificar se existem inconsistências ortográficas que podem causar problemas em junções ou transformações nos dados;*

# %% [markdown]
# Algumas colunas como causa_acidente, tipo_acidente, dia_semana, estado_fisico e condicao_metereologica possuem atributos repetidos e algumas inconsistências ortográficas. A coluna de data_inversa foi alterada para o tipo 'datetime' para facilitar o manejo dessas informações.

# %% [markdown]
# *(iii) Verificar se há desvios nos valores dos dados (outliers) e se isso é ruído ou tem algum significado;*

# %%
#Histogramas das variáveis numéricas.
datatran_381_262.hist(figsize=(12,10));
plt.tight_layout()

# %%
apessoa_381_262.hist(figsize=(12,10));
plt.tight_layout()

# %%
apessoa_381_262['idade'].describe()
# Out:
# count    47160.000000
# mean        40.392345
# std         65.705437
# min          0.000000
# 25%         27.000000
# 50%         37.000000
# 75%         48.000000
# max       2019.000000
# Name: idade, dtype: float64

# %%
#apessoa_381_262['idade'].plot(kind='box', vert=False);
px.box(apessoa_381_262, y='idade')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="39abfde2-5572-4264-ae92-cccf5de70e0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39abfde2-5572-4264-ae92-cccf5de70e0b")) {
#                     Plotly.newPlot(
#                         '39abfde2-5572-4264-ae92-cccf5de70e0b',
# ...

# %% [markdown]
# É possível notar através dos histogramas e do gráfico de boxplot acima que a coluna de idade do dataframe de acidentes agrupados por pessoa contêm outliers.

# %% [markdown]
# *(iv) Verificar a possibilidade de excluir dados que não tenham impacto nas hipóteses;*

# %% [markdown]
# <p align='justify'>As colunas de latitude, longitude, regional, delegacia e uop, contidas no dataframe de acidentes agrupados por ocorrência podem ser excluídos , pois não trazem impacto para o estudo, assim como as colunas de nacionalidade e naturalidade, existentes nos dataframes de  acidentes agrupados por pessoa.</p>

# %% [markdown]
# *(v) Verificar se os dados estão corretamente separados por delimitadores e se há o mesmo número de campos em cada linha;*

# %% [markdown]
# Os dados estão corretos.

# %% [markdown]
# # **3. PREPARAÇÃO DOS DADOS**

# %% [markdown]
# # **3.1 Selecionando os dados**

# %% [markdown]
# *(i) Verificar a existência de atributos especialmente relevantes para os objetivos da mineração de dados;*

# %% [markdown]
# O horário e o dia da semana podem ser usados para determinar a sazonalidade dos acidentes e ocorrências, as causas dos acidentes e a classificação do mesmo, como a quantidade de mortos, pode ser usada para verificar a letalidade desses casos.

# %% [markdown]
# *(ii) Identificar se há problemas de qualidade em um conjunto de dados ou um atributo que possa comprometer a validade dos resultados;*

# %% [markdown]
# Os dataframes de 2017 em diante possuem algumas colunas inexistentes no dataframe de 2016, assim como, o de 2016 possui informações que não podem ser encontradas nos dos anos seguintes.

# %% [markdown]
# *(iii) Verificar a possibilidade e as formas de sanar esses problemas;*

# %% [markdown]
# Muitas dessas informações não serão usadas neste estudo, podendo serem excluídas.

# %% [markdown]
# *(iv) Verificar se há alguma restrição quanto ao uso de atributos específicos;*

# %% [markdown]
# Não há restrinções quanto ao uso de atributos.

# %% [markdown]
# # **3.2	Limpando os dados**

# %%
datatran_381_262 = datatran_381_262.replace({'Ceu Claro': 'Céu Claro'})
datatran_381_262 = datatran_381_262.replace({'Ignorada': 'Ignorado'})
datatran_381_262 = datatran_381_262.replace({'Nevoeiro/neblina': 'Nevoeiro/Neblina'})

apessoa_381_262 = apessoa_381_262.replace({'Ceu Claro': 'Céu Claro'})
apessoa_381_262 = apessoa_381_262.replace({'CÃ©u Claro': 'Céu Claro'})
apessoa_381_262 = apessoa_381_262.replace({'Nevoeiro/neblina': 'Nevoeiro/Neblina'})
apessoa_381_262 = apessoa_381_262.replace({'Ignorada': 'Ignorado'})

# %% [markdown]
# *- Acidentes agrupados por ocorrência.*

# %%
#Coletando a condicao metereologica mais frequente.
print(datatran_381_262.condicao_metereologica.value_counts())
freq = datatran_381.condicao_metereologica.value_counts()[0]
# Out:
# Céu Claro           10642
# Chuva                5223
# Nublado              3915
# Sol                  1991
# Garoa/Chuvisco        391
# Ignorado              369
# Nevoeiro/Neblina      172
# Vento                  53
# Granizo                 3
# Name: condicao_metereologica, dtype: int64

# %%
#Substituindo o local onde o valor era nulo com o mais frequente.
datatran_381_262.condicao_metereologica.fillna(freq, inplace=True)

# %%
#Como nesse estudo não usaremos informacoes de "latitude, longitude, regional, delegacia e uop", essas colunas podem ser descartadas.
datatran_381_262.drop([
                     'latitude',
                     'longitude',
                     'regional',
                     'delegacia',
                     'uop'
                 ], axis=1, inplace=True)

# %%
datatran_381_262.isnull().sum() #Verificando se todos os valores nulos foram tratados.
# Out:
# id                        0
# data_inversa              0
# uf                        0
# br                        0
# km                        0
# municipio                 0
# causa_acidente            0
# tipo_acidente             0
# classificacao_acidente    0
# fase_dia                  0
# sentido_via               0
# condicao_metereologica    0
# tipo_pista                0
# tracado_via               0
# uso_solo                  0
# pessoas                   0
# mortos                    0
# feridos_leves             0
# feridos_graves            0
# ilesos                    0
# ignorados                 0
# feridos                   0
# veiculos                  0
# Contagem                  0
# hora                      0
# dia_da_semana             0
# ano                       0
# dtype: int64

# %%
#datatran_381_262 = datatran_381_262.replace({'NÃ£o guardar distÃ¢ncia de seguranÃ§a	': 'Não guardar distância de segurança'})
datatran_381_262 = datatran_381_262.replace(['NÃ£o guardar distÃ¢ncia de seguranÃ§a'], 'Não guardar distância de segurança')

# %%
datatran_381_262 = datatran_381_262.replace({'Velocidade incompatível': 'Velocidade Incompatível'})
datatran_381_262 = datatran_381_262.replace({'Velocidade incompatÃ­vel': 'Velocidade Incompatível'})

datatran_381_262 = datatran_381_262.replace({'Ingestão de álcool': 'Ingestão de Álcool'})
datatran_381_262 = datatran_381_262.replace({'IngestÃ£o de Ã¡lcool': 'Ingestão de Álcool'})

datatran_381_262 = datatran_381_262.replace({'Defeito mecânico em veículo': 'Defeito Mecânico no Veículo'})
datatran_381_262 = datatran_381_262.replace({'Defeito mecÃ¢nico em veÃ­culo': 'Defeito Mecânico no Veículo'})

datatran_381_262 = datatran_381_262.replace({'Ultrapassagem indevida': 'Ultrapassagem Indevida'})

datatran_381_262 = datatran_381_262.replace({'Defeito na via': 'Defeito na Via'})

datatran_381_262 = datatran_381_262.replace({'Dormindo': 'Condutor Dormindo'})

datatran_381_262 = datatran_381_262.replace({'Falta de atenÃ§Ã£o': 'Falta de atenção'})

datatran_381_262 = datatran_381_262.replace({'Ausência de sinalização': 'Sinalização da via insuficiente ou inadequada'})

# %% [markdown]
# *- Acidentes agrupados por pessoa.*

# %%
apessoa_381_262.drop([
                     'marca',
                     'ano_fabricacao_veiculo',
                     'nacionalidade',
                     'naturalidade',
                     'idade',
                     'latitude',
                     'longitude',
                     'regional',
                     'delegacia',
                     'uop'
                 ], axis=1, inplace=True)

# %%
#Coletando a condicao metereologica mais frequente.
print(apessoa_381_262.condicao_metereologica.value_counts())
freq = apessoa_381_262.condicao_metereologica.value_counts()[0]
# Out:
# Céu Claro           24681
# Chuva               11050
# Nublado              8827
# Sol                  4593
# Garoa/Chuvisco        973
# Ignorado              731
# Nevoeiro/Neblina      422
# Vento                 110
# Granizo                 4
# Name: condicao_metereologica, dtype: int64

# %%
#Substituindo o local onde o valor era nulo com o mais frequente.
apessoa_381_262.condicao_metereologica.fillna(freq, inplace=True)

# %%
apessoa_381_262.isnull().sum()
# Out:
# id                            0
# pesid                         0
# data_inversa                  0
# uf                            0
# br                            0
# km                            0
# municipio                     0
# causa_acidente                0
# tipo_acidente                 0
# classificacao_acidente        0
# fase_dia                      0
# sentido_via                   0
# condicao_metereologica        0
# tipo_pista                    0
# tracado_via                   0
# uso_solo                      0
# id_veiculo                  166
# tipo_veiculo                166
# tipo_envolvido                0
# estado_fisico                 0
# sexo                          0
# ilesos                    12779
# feridos_leves             12779
# feridos_graves            12779
# mortos                    12779
# Contagem                      0
# hora                          0
# dia_da_semana                 0
# ano                           0
# ...

# %%
print(apessoa_381_262.estado_fisico.value_counts())
# Out:
# Ileso             23050
# Lesões Leves      12065
# Ferido Leve        4478
# LesÃµes Leves      3542
# Lesões Graves      2712
# Não Informado      1349
# Ferido Grave       1162
# LesÃµes Graves      848
# Óbito               809
# NÃ£o Informado      435
# Ignorado            388
# Morto               294
# Ãbito              262
# Name: estado_fisico, dtype: int64

# %%
apessoa_381_262 = apessoa_381_262.replace({'LesÃµes Leves': 'Lesões Leves'})
apessoa_381_262 = apessoa_381_262.replace({'LesÃµes Graves': 'Lesões Graves'})
apessoa_381_262 = apessoa_381_262.replace({'NÃ£o Informado': 'Não Informado'})
apessoa_381_262 = apessoa_381_262.replace({'Ãbito': 'Óbito'})
apessoa_381_262 = apessoa_381_262.replace({'Morto': 'Óbito'})
apessoa_381_262 = apessoa_381_262.replace({'Ferido Leve': 'Lesões Leves'})
apessoa_381_262 = apessoa_381_262.replace({'Ferido Grave': 'Lesões Graves'})
apessoa_381_262 = apessoa_381_262.replace({'Ignorado': 'Não Informado'})

# %%
print(apessoa_381_262.estado_fisico.value_counts())
# Out:
# Ileso            23050
# Lesões Leves     20085
# Lesões Graves     4722
# Não Informado     2172
# Óbito             1365
# Name: estado_fisico, dtype: int64

# %%
apessoa_381_262.loc[apessoa_381_262['estado_fisico'] == 'Ileso', 'ilesos'] = 1

# %%
apessoa_381_262['ilesos'].fillna(0, inplace = True)

# %%
apessoa_381_262.loc[apessoa_381_262['estado_fisico'] == 'Lesões Leves', 'feridos_leves'] = 1

# %%
apessoa_381_262['feridos_leves'].fillna(0, inplace = True)

# %%
apessoa_381_262.loc[apessoa_381_262['estado_fisico'] == 'Lesões Graves', 'feridos_graves'] = 1

# %%
apessoa_381_262['feridos_graves'].fillna(0, inplace = True)

# %%
apessoa_381_262.loc[apessoa_381_262['estado_fisico'] == 'Óbito', 'mortos'] = 1

# %%
apessoa_381_262['mortos'].fillna(0, inplace = True)

# %%
apessoa_381_262.isnull().sum()
# Out:
# id                          0
# pesid                       0
# data_inversa                0
# uf                          0
# br                          0
# km                          0
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# id_veiculo                166
# tipo_veiculo              166
# tipo_envolvido              0
# estado_fisico               0
# sexo                        0
# ilesos                      0
# feridos_leves               0
# feridos_graves              0
# mortos                      0
# Contagem                    0
# hora                        0
# dia_da_semana               0
# ano                         0
# dtype: int64

# %%
#tipo_veiculo
apessoa_381_262 = apessoa_381_262.replace(['CaminhÃ£o'], 'Caminhão')
apessoa_381_262 = apessoa_381_262.replace({'CaminhÃ£o-trator': 'Caminhão-trator'})
apessoa_381_262 = apessoa_381_262.replace({'Caminhão-Trator': 'Caminhão-trator'})
apessoa_381_262 = apessoa_381_262.replace({'CaminhÃ£o-Trator': 'Caminhão-trator'})

apessoa_381_262 = apessoa_381_262.replace({'CaminhÃ£o-Tanque': 'Caminhão-tanque'})

apessoa_381_262 = apessoa_381_262.replace({'AutomÃ³vel': 'Automóvel'})
apessoa_381_262 = apessoa_381_262.replace({'Ãnibus': 'Ônibus'})
apessoa_381_262 = apessoa_381_262.replace({'UtilitÃ¡rio': 'Utilitário'})

apessoa_381_262 = apessoa_381_262.replace({'NÃ£o Informado': 'Não Informado'})
apessoa_381_262 = apessoa_381_262.replace({'NÃ£o identificado': 'Não Informado'})

apessoa_381_262 = apessoa_381_262.replace({'Micro-Ã´nibus': 'Micro-ônibus'})
apessoa_381_262 = apessoa_381_262.replace({'MicroÃ´nibus': 'Micro-ônibus'})
apessoa_381_262 = apessoa_381_262.replace({'Microônibus': 'Micro-ônibus'})

apessoa_381_262 = apessoa_381_262.replace({'CarroÃ§a-charrete': 'Carroça-charrete'})
apessoa_381_262 = apessoa_381_262.replace({'Semi-Reboque': 'Semireboque'})

apessoa_381_262 = apessoa_381_262.replace({'CarroÃ§a': 'Carroça'})

# %%
#Coletando o tipo de veiculo mais frequente.
print(apessoa_381_262.tipo_veiculo.value_counts())
freq = apessoa_381_262.tipo_veiculo.value_counts()[0]
# Out:
# Automóvel            25000
# Caminhão-trator       5470
# Motocicleta           5179
# Caminhão              4612
# Caminhonete           4299
# Ônibus                2391
# Camioneta             1322
# Motocicletas          1278
# Micro-ônibus           473
# Utilitário             469
# Bicicleta              287
# Motoneta               170
# Outros                  91
# Semireboque             81
# Não Informado           43
# Ciclomotor              24
# Reboque                 11
# Trator de rodas         11
# Triciclo                 8
# Carroça                  2
# Carroça-charrete         2
# Caminhão-tanque          2
# Trator de esteira        1
# Chassi-plataforma        1
# Motor-Casa               1
# Name: tipo_veiculo, dtype: int64

# %%
#Substituindo o local onde o valor era nulo com o mais frequente.
apessoa_381_262.tipo_veiculo.fillna(freq, inplace=True)

# %%
apessoa_381_262.isnull().sum()
# Out:
# id                          0
# pesid                       0
# data_inversa                0
# uf                          0
# br                          0
# km                          0
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# id_veiculo                166
# tipo_veiculo                0
# tipo_envolvido              0
# estado_fisico               0
# sexo                        0
# ilesos                      0
# feridos_leves               0
# feridos_graves              0
# mortos                      0
# Contagem                    0
# hora                        0
# dia_da_semana               0
# ano                         0
# dtype: int64

# %% [markdown]
# *(iv) Relatar se houve atributos com ruídos que não puderam ser recuperados.*

# %% [markdown]
# Não houve.

# %% [markdown]
# # **3.3	Construindo novos dados**

# %% [markdown]
# *(i) Verificar se os dados estão de acordo com o que é esperado pelo algoritmo de mineração de dados escolhido e, se preciso, realizar as transformações necessárias; (ii) Se preciso, realizar a normalização de atributos);*

# %% [markdown]
# Os dados estão de acordo com o esperado não necessitando de normalização.

# %% [markdown]
# *(iii) Verificar a possibilidade de se criar atributos relevantes a partir dos atributos existentes;*

# %% [markdown]
# É possível criar novos atributos a partir de data_inversa e fazer uma classificação dos veículos a partir de tipo_veiculo quanto a tração, espécie e até mesmo, categoria.

# %% [markdown]
# *(iv) Verificar a necessidade de se aplicar oversampling ou undersampling no caso de bases desbalanceadas;*

# %% [markdown]
# oversamplig: id_veiculo, longitude, latitude, naturalidade, nacionalidade, regional, delegacia e uop.

# %% [markdown]
# *(vi) Efetuar a geração de novos atributos e registros.*

# %% [markdown]
# Foi criado as colunas de ano, dia_da_semana e hora a partir de data_inversa. A coluna de contagem também foi criada.

# %% [markdown]
# *=========================================*

# %%
df1 = datatran_381_262.groupby(['causa_acidente', 'ano'], as_index=False)[['mortos', 'Contagem']].sum()

# %%
df1
# Out:
#               causa_acidente   ano  mortos  Contagem
# 0           Agressão Externa  2017       0         1
# 1           Agressão Externa  2018       0        16
# 2           Agressão Externa  2019       0        19
# 3           Agressão Externa  2020       1        10
# 4           Animais na Pista  2016       2        88
# ..                       ...   ...     ...       ...
# 103  Velocidade Incompatível  2016     112      2028
# 104  Velocidade Incompatível  2017     119      1699
# 105  Velocidade Incompatível  2018      80      1078
# 106  Velocidade Incompatível  2019      56       821
# 107  Velocidade Incompatível  2020      72       795
#
# [108 rows x 4 columns]

# %%
df1 = df1.groupby(['ano'], as_index=False)[['mortos', 'Contagem']].apply(sum)

# %%
df1
# Out:
#     ano  mortos  Contagem
# 0  2016     294      6153
# 1  2017     319      5561
# 2  2018     260      3957
# 3  2019     230      3606
# 4  2020     262      3483

# %% [markdown]
# *Questão 2 - Como tem sido a progressão desses casos nos últimos 5 anos? Tiveram menos ocorrências ou mais? As ocorrências estão mais fatais?*

# %%
ano = df1['ano'].tolist()
contagem = df1['Contagem'].tolist()
mortos = df1['mortos'].tolist()

fig = go.Figure(data=[
                    go.Bar(name='Ocorrências', x=ano, y=contagem),
                    go.Bar(name='Vítimas Fatais', x=ano, y=mortos)
])
fig.update_layout(yaxis={'title': 'Quantidade'})
fig.update_layout(xaxis={'title': 'Ano'})
fig.update_layout(title={'text': 'Progressão de Ocorrências e Ocorrências com Vítimas Fatais BR 381 e 262 - MG'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8ba1c86c-2a7d-40c6-975f-d9beb0191c5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ba1c86c-2a7d-40c6-975f-d9beb0191c5b")) {
#                     Plotly.newPlot(
#                         '8ba1c86c-2a7d-40c6-975f-d9beb0191c5b',
# ...

# %%
correlacao = datatran_381_262.corr().dropna(axis=0, how='all').dropna(axis=1, how='all') 
display(correlacao)
# Out:
#                       id        br   pessoas  ...      hora  dia_da_semana       ano
# id              1.000000  0.010211 -0.050438  ...  0.013429      -0.013433 -0.722544
# br              0.010211  1.000000  0.006690  ... -0.042199      -0.025398 -0.022000
# pessoas        -0.050438  0.006690  1.000000  ...  0.010800       0.018453  0.055474
# mortos         -0.023740 -0.034470  0.227805  ...  0.013604      -0.003249  0.028379
# feridos_leves  -0.073600 -0.016051  0.599890  ... -0.008887       0.020661  0.094535
# feridos_graves -0.018631 -0.042673  0.321393  ...  0.007183       0.030386  0.044756
# ilesos          0.014305  0.051839  0.706479  ...  0.015535      -0.008116 -0.036768
# ignorados      -0.051974 -0.023217  0.150807  ...  0.005988       0.024257  0.056970
# feridos        -0.073312 -0.032207  0.668755  ... -0.004890       0.031147  0.102913
# veiculos       -0.028689  0.019432  0.473144  ...  0.056579      -0.028221  0.054376
# ...

# %%
plt.figure(figsize = (16,5))
sn.heatmap(correlacao, annot=True)

# %%
correlacao = apessoa_381_262.corr().dropna(axis=0, how='all').dropna(axis=1, how='all') 
display(correlacao)
# Out:
#                       id     pesid        br  ...      hora  dia_da_semana       ano
# id              1.000000  0.999995 -0.007149  ...  0.027003      -0.010256 -0.715966
# pesid           0.999995  1.000000 -0.007176  ...  0.027117      -0.010244 -0.714028
# br             -0.007149 -0.007176  1.000000  ... -0.043185      -0.009711 -0.001173
# id_veiculo      0.999865  0.999910 -0.007071  ...  0.024697      -0.010110 -0.703220
# ilesos          0.065500  0.065274  0.065968  ...  0.012089      -0.027192 -0.099495
# feridos_leves  -0.047511 -0.047387 -0.023881  ... -0.018786       0.009638  0.066806
# feridos_graves -0.001794 -0.001677 -0.041618  ...  0.003383       0.022313  0.024491
# mortos         -0.012681 -0.012644 -0.030800  ...  0.010022      -0.005716  0.015570
# hora            0.027003  0.027117 -0.043185  ...  1.000000       0.031939  0.008714
# dia_da_semana  -0.010256 -0.010244 -0.009711  ...  0.031939       1.000000  0.005135
# ...

# %%
plt.figure(figsize = (16,5))
sn.heatmap(correlacao, annot=True)

# %%
df1 = datatran_381_262.groupby(['causa_acidente'], as_index=False)[['mortos', 'Contagem']].sum()

# %%
df1
# Out:
#                                        causa_acidente  mortos  Contagem
# 0                                    Agressão Externa       1        46
# 1                                    Animais na Pista       7       334
# 2             Avarias e/ou desgaste excessivo no pneu       4       217
# 3              Carga excessiva e/ou mal acondicionada       4       111
# 4                                               Chuva       0         2
# 5                                   Condutor Dormindo     102      1599
# 6                         Defeito Mecânico no Veículo      44      1358
# 7                                      Defeito na Via       0       120
# 8   Deficiência ou não Acionamento do Sistema de I...       0        14
# 9                     DesobediÃªncia Ã  sinalizaÃ§Ã£o       8       152
# 10  Desobediência às normas de trânsito pelo condutor      76       934
# 11  Desobediência às normas de trânsito pelo pedestre      15        47
# ...

# %% [markdown]
# # **3.4	Integrando os dados**

# %% [markdown]
# *(i) Integrar (importação de linhas ou colunas) os conjuntos de dados considerados úteis para a mineração de dados;*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Gerar uma base única de dados para a mineração de dados);*

# %% [markdown]
# xxx

# %% [markdown]
# *(iii) Verificar a necessidade de construção de novos dados.*

# %% [markdown]
# # **3.5	Formatando os dados**

# %% [markdown]
# *(i) Verificar as formatações necessárias para utilização da ferramenta de mineração de dados escolhida;*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Transpor a base de dados para o formato apropriado.*

# %% [markdown]
# xxx

# %% [markdown]
# # **4. MODELAGEM**

# %% [markdown]
# # **4.1	Selecionando a(s) técnica(s) de modelagem**

# %% [markdown]
# *(i) Verificar se o modelo a ser criado requer o particionamento dos dados em dados de treinamento e de teste;*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Verificar se há dados suficientes para se produzir um modelo confiável);*

# %% [markdown]
# Há dados suficientes.

# %% [markdown]
# *(iii) Verificar se os dados possuem qualidade suficiente para se produzir um modelo confiável;*

# %% [markdown]
# xxx

# %% [markdown]
# *(iv) Verificar se os tipos de dados são apropriados para o modelo a ser construído;*

# %% [markdown]
# xxx

# %% [markdown]
# *(v) Adequar os dados às necessidades da técnica de mineração de dados a ser utilizada.*

# %% [markdown]
# xxx

# %% [markdown]
# # **4.2	Projetando o teste**

# %% [markdown]
# *(i) Especificar o esquema de teste do modelo a ser criado (ex: utilização de máquinas de comitê, separação da base de dados em treinamento e teste, parâmetros para essa divisão, etc);*

# %% [markdown]
# xxx

# %%
datatran_381_262['mes_ano'] = datatran_381_262['data_inversa'].dt.to_period('M')

# %%
df = datatran_381_262.groupby(['mes_ano'], as_index=True)[['mortos', 'feridos', 'Contagem']].sum()

# %%
df
# Out:
#          mortos  feridos  Contagem
# mes_ano
# 2016-01      23      646       652
# 2016-02      18      379       435
# 2016-03      27      449       547
# 2016-04      32      456       486
# 2016-05      23      412       450
# 2016-06      28      401       496
# 2016-07      20      506       446
# 2016-08      21      427       470
# 2016-09      18      361       404
# 2016-10      29      516       547
# 2016-11      19      564       605
# 2016-12      36      523       615
# 2017-01      33      602       535
# 2017-02      34      509       505
# 2017-03      21      411       418
# 2017-04      23      415       430
# 2017-05      29      419       500
# 2017-06      29      407       409
# 2017-07      30      430       411
# 2017-08      23      350       380
# 2017-09      15      398       396
# 2017-10      17      432       487
# 2017-11      50      469       477
# 2017-12      15      568       613
# 2018-01      26      470       491
# ...

# %%
df.plot(figsize=(15,6))

# %%
df.Contagem.plot(figsize=(15,6))

# %% [markdown]
# *Média móvel - eliminação de ruídos*

# %% [markdown]
# *Questão 7 - Qual é a média móvel dos acidentes nos últimos 5 anos (acidentes, feridos, mortes)?*

# %%
#Plotando para 12 períodos
df.Contagem.rolling(12).mean().plot(figsize=(15,6))

# %%
df.feridos.rolling(12).mean().plot(figsize=(15,6))

# %%
df.mortos.rolling(12).mean().plot(figsize=(15,6))

# %%
df.Contagem.groupby(df.index.year).sum().plot(figsize=(15,6))

# %% [markdown]
# *Analisando sazionalidade*

# %%
#Necessário eliminação da tendência utilizando o conceito de diferenças.
df.Contagem.diff().plot(figsize=(15,6))

# %%
df.Contagem.diff().groupby(df.index.month).mean().plot(kind='bar')

# %% [markdown]
# *Questão 6 - O aumento de acidentes tem relação à sazonalidade (períodos de festas, de férias)?*
#
# A partir do gráfico acima podemos observar que durante as férias de fim de ano é possível perceber uma sazionalidade no aumento de casos. Em contra partida após as festividades de fim de ano, este é o período com menos acidentes.

# %% [markdown]
# *(ii) Definir qual a medida de sucesso para modelos;*

# %% [markdown]
# xxx

# %% [markdown]
# *(iii) Definir estratégias para se testar um modelo quanto à sua efetividade em relação aos objetivos da mineração de dados.*

# %% [markdown]
# xxx

# %% [markdown]
# # **4.3 Construindo o(s) modelo(s)**

# %% [markdown]
# *(i) Calibrar os parâmetros do algoritmo que implementa a técnica de modelagem escolhida;*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Gerar o(s) modelo(s);*

# %% [markdown]
# xxx

# %% [markdown]
# *(iii) Descrever os resultados do(s) modelo(s), incluindo indicadores de desempenho, problemas durante a execução e achados a partir da exploração do modelo (ex: novos insights, padrões úteis, problemas de execução e inconsistências).*

# %% [markdown]
# xxx

# %% [markdown]
# # **4.4	Avaliando o(s) modelo(s)**

# %% [markdown]
# *(i) Avaliar os resultados do(s) modelo(s), considerando os indicadores de qualidade;*

# %% [markdown]
# xxx

# %% [markdown]
# *(ii) Realizar uma revisão dos resultados baseado no entendimento do problema do negócio (na perspectiva dos cientistas de dados e dos especialistas do negócio);*

# %% [markdown]
# xxx

# %% [markdown]
# *(iii) Verificar se os resultados dos modelos são facilmente aproveitáveis na prática;*

# %% [markdown]
# xxx

# %% [markdown]
# *(iv) Analisar o impacto dos resultados dos modelos tendo em vista os critérios de sucesso da mineração definidos anteriormente;*

# %% [markdown]
# xxx

# %% [markdown]
# *(v) Ranquear o(s) modelos, escolher o(s) modelo(s) mais adequado(s) para solucionar o problema de negócio e fundamentar essa escolha.*

# %% [markdown]
# xxx
